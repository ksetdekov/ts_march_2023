# %%
from scipy.datasets import electrocardiogram
from scipy.signal import periodogram
ecg = electrocardiogram()

f, ppx = periodogram(ecg)
list(sorted(zip(f, ppx), key=lambda x: x[1]))[-1]
# Out:
# (0.0003148148148148148, 1763.2423924280758)

# %%
print(f'длина периода {1/0.0003148148148148148}')
# Out:
# длина периода 3176.470588235294
